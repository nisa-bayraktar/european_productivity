# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
dep = pd.read_csv('../data/depression_data.csv') 
prod = pd.read_csv('../data/productivity.csv')
prod = prod.drop(['Unnamed: 18'],axis=1)
prod = prod.drop(['2020'],axis=1)
depres = pd.DataFrame(dep)
productivity = pd.DataFrame(prod)
depression= depres.pivot_table('Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)', ['Entity', 'Code'], 'Year')
#arr = df2['Country'].unique()

#df3 = df1.set_index(['Entity','Code','Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)','Year'],drop=True).unstack('Year')
#df3
arr = depres['Entity'].unique()
arr1=productivity['Country'].unique()

arr2 = []
for name in arr:
    for name2 in arr1:
        if(name == name2):
            arr2.append(name2)




#depres.columns
#print(arr2)

# %%
depression = depression.loc[arr2]
depression = depression.iloc[:,15:]
depression
# Out:
# Year                2005      2006      2007      2008      2009      2010  \
# Entity    Code
# Austria   AUT   3.518856  3.487676  3.452370  3.420009  3.394998  3.382760
# Belgium   BEL   3.727437  3.774368  3.844750  3.920219  3.980250  4.006651
# Bulgaria  BGR   2.986497  2.965492  2.942433  2.922038  2.904749  2.891473
# Croatia   HRV   3.365967  3.341534  3.315726  3.291660  3.272489  3.259025
# Denmark   DNK   3.983236  3.952828  3.929574  3.911470  3.899650  3.891963
# Finland   FIN   4.943536  4.940856  4.961964  4.994505  5.018156  5.015278
# Germany   DEU   3.774823  3.785681  3.804806  3.831156  3.850289  3.856827
# Greece    GRC   6.065459  6.067747  6.075770  6.083488  6.089800  6.086848
# Hungary   HUN   3.168091  3.146143  3.125211  3.107033  3.090194  3.073663
# Iceland   ISL   3.248086  3.221052  3.192239  3.167305  3.150774  3.147767
# Ireland   IRL   4.639991  4.636603  4.631230  4.625995  4.618536  4.608753
# ...

# %%
#for n in range (len(productivity['Country'])):
    #if 

#index = productivity.index.values.astype(int)
#index
#if(index.mod(2) != 0).

# %%
#productivity.drop(productivity.index[productivity['Country']=='Macedonia'])

productivity = productivity[productivity['Country'].notna()]

a=[]
for i in range(0,61):
    if i%2 != 0:
        a.append(i)

productivity = productivity.drop(a)


productivity['Average_Productivity']=productivity.iloc[:,2:20].mean(axis=1,skipna=True)
productivity = productivity.reset_index(drop=True)
# Out:
# /var/folders/2k/j21zjx350njdf7pt9pvz2js40000gn/T/ipykernel_59055/3668892013.py:13: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   productivity['Average_Productivity']=productivity.iloc[:,2:20].mean(axis=1,skipna=True)

# %%
#a=[5.097348,5.097591,5.098612,5.096508,5.097203,5.098864,5.100837,5.103256,5.106234,5.109784,5.113303,5.111760,5.111567,5.119865,5.131458]
#np.mean(a)

# %%
depression['Average_Depression'] = depression.iloc[:,0:14].mean(axis=1,skipna=True)
depression
# Out:
# Year                2005      2006      2007      2008      2009      2010  \
# Entity    Code
# Austria   AUT   3.518856  3.487676  3.452370  3.420009  3.394998  3.382760
# Belgium   BEL   3.727437  3.774368  3.844750  3.920219  3.980250  4.006651
# Bulgaria  BGR   2.986497  2.965492  2.942433  2.922038  2.904749  2.891473
# Croatia   HRV   3.365967  3.341534  3.315726  3.291660  3.272489  3.259025
# Denmark   DNK   3.983236  3.952828  3.929574  3.911470  3.899650  3.891963
# Finland   FIN   4.943536  4.940856  4.961964  4.994505  5.018156  5.015278
# Germany   DEU   3.774823  3.785681  3.804806  3.831156  3.850289  3.856827
# Greece    GRC   6.065459  6.067747  6.075770  6.083488  6.089800  6.086848
# Hungary   HUN   3.168091  3.146143  3.125211  3.107033  3.090194  3.073663
# Iceland   ISL   3.248086  3.221052  3.192239  3.167305  3.150774  3.147767
# Ireland   IRL   4.639991  4.636603  4.631230  4.625995  4.618536  4.608753
# ...

# %%
x = x.reshape(len(productivity), 1)
y = y.reshape(len(depression), 1)

correl_signif = pearsonr(x, y)
correl = correl_signif[0]
correl
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2k/j21zjx350njdf7pt9pvz2js40000gn/T/ipykernel_59055/2022035689.py in <module>
#       2 y = y.reshape(len(depression), 1)
#       3
# ----> 4 correl_signif = pearsonr(x, y)
#       5 correl = correl_signif[0]
#       6 correl
#
# /usr/local/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    4011     n = len(x)
#    4012     if n != len(y):
# -> 4013         raise ValueError('x and y must have the same length.')
#    4014
#    4015     if n < 2:
#
# ValueError: x and y must have the same length.

# %%
import matplotlib.pyplot as plt

x=productivity.loc[:,'Average_Productivity'].values
y=depression.loc[:,'Average_Depression'].values

x = x.reshape(len(productivity), 1)
y = y.reshape(len(depression), 1)

from sklearn.linear_model import LinearRegression

regr = LinearRegression()
regr.fit(x, y)
print(regr.score(x, y))


fig, ax = plt.subplots(dpi=100, figsize=(6, 4))
fig.patch.set_facecolor('white')
ax.scatter(x, y,  color='black', label='data')
ax.plot(x, regr.predict(x), color='blue', linewidth=3, label='regression')

ax.set_xlabel('Productivity', fontsize=10)
ax.set_ylabel('Depression', fontsize=10)

ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2k/j21zjx350njdf7pt9pvz2js40000gn/T/ipykernel_59055/4184744629.py in <module>
#      10
#      11 regr = LinearRegression()
# ---> 12 regr.fit(x, y)
#      13 print(regr.score(x, y))
#      14
#
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...
