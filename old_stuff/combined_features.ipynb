# %%
#coding utf8
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import tensorflow as tf
import keras_tuner as kt
from tensorflow import keras
from tensorflow.keras import layers, metrics
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor, AdaBoostRegressor
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn import svm
import statsmodels.api as sm
from pylab import rcParams
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.feature_selection import mutual_info_regression, f_regression, r_regression
import sklearn
from neuralprophet import NeuralProphet

# %%
'''
Functions for loading in and combining data
'''
def load_df(file_name, sheet = 'Sheet 1'):
    '''
    Load a file into a data frame that is quarterly from the Eurostat website
    '''
    df = pd.read_excel(file_name, sheet_name=sheet)
    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
    df.replace(':', np.nan, inplace=True)
    df.index = df.iloc[:, 0]
    df.drop(df.columns[[0]], axis=1, inplace=True)
    for i in df.columns[:]:
        df[i] = df[i].apply(pd.to_numeric, errors="coerce")
    df.interpolate(method='linear', inplace=True, axis = 1)
    df.sort_index(inplace=True)
    df = df.rename({'Germany (until 1990 former territory of the FRG)': 'Germany'})
    return df

def create_per_employeer(GDP_df, HW_df, employees_df):
    ''' 
    Inputs: GDP, hours worked, and employees dataframes
    Output: dataframe with per-employee GDP and per hour worked GDP
    '''
    cols =(list(set(GDP_df.columns) and set(employees_df.columns) and set(HW_df.columns)))
    cols.sort()
    idx = cols.pop()
    per_employee_df = pd.DataFrame(index=GDP_df.index, columns=cols)
    per_HW_df = pd.DataFrame(index=GDP_df.index, columns=cols)
    for i in cols:
        per_employee_df[i] = GDP_df[i]/employees_df[i]
        per_HW_df[i] = per_employee_df[i]/HW_df[i]
    return per_employee_df, per_HW_df

def country_code_to_name(df):
    '''
    Renames country codes to country names
    '''
    df = df.rename({'AUT': 'Austria', 'BEL': 'Belgium', 'DEU': 'Germany','EST': 'Estonia','FIN': 'Finland','ESP': 'Spain','FRA': 'France','GRC': 'Greece','IRL': 'Ireland','ITA': 'Italy','LTU': 'Lithuania','LUX': 'Luxembourg','LVA': 'Latvia','PRT': 'Portugal','NLD': 'Netherlands','SVK': 'Slovakia','SVN': 'Slovenia','ISL': 'Iceland','GBR': 'United Kingdom','CHE': 'Switzerland','CZE': 'Cezch Republic','DNK': 'Denmark','HUN': 'Hungary','NOR': 'Norway','POL': 'Poland','SWE': 'Sweden'})
    return df

def yearly_to_quarterly(df):
    '''
    Inputs: df
    Converts the data from yearly to quarterly
    Outputs: quarterly_df
    '''
    data = df.to_numpy(dtype=np.float64)
    data = np.repeat(data, 4, axis = 1)
    quarterly_df = pd.DataFrame(data)
    quarterly_df.index = df.index
    quarterly_df.columns = GDP_df.columns[(int(df.columns[0]) - 1975)*4:(int(df.columns[-1]) - 2021)*4]
    return quarterly_df

def match_df(dfs):
    ''' 
    Input : dataframes
    This function matches dataframes by their index and column 
    Output: matched dataframes
    '''
    idx = set(dfs[0].index)
    cols = set(dfs[0].columns)
    for i in dfs:
        idx = idx.intersection(set(i.index))
        cols = cols.intersection(set(i.columns))
    cols = list(cols)
    idx = list(idx)
    cols.sort()
    idx.sort()
    for i in range(len(dfs)):
        dfs[i] = dfs[i].loc[idx]
        dfs[i] = dfs[i][cols]
    return dfs

def to_datetime(df):
    df.columns = [w.replace('-Q1','-01') for w in df.columns]
    df.columns = [w.replace('-Q2','-04') for w in df.columns]
    df.columns = [w.replace('-Q3', '-07') for w in df.columns]
    df.columns = [w.replace('-Q4', '-10') for w in df.columns]
    for i in df.columns[:]:
        i = np.datetime64(i)
    df.columns = pd.to_datetime(df.columns)
    return df

def extend_df(dfs):
    idx = set(dfs[0].index)
    cols = set(dfs[0].columns)
    for i in dfs:
        idx = idx.union(set(i.index))
        cols = cols.union(set(i.columns))
    cols = list(cols)
    idx = list(idx)
    cols.sort()
    idx.sort()
    for i in range(len(dfs)):
        dfs[i] = dfs[i].reindex(index=idx, columns=cols)
        dfs[i] = dfs[i].loc[idx]
        dfs[i] = dfs[i][cols]
        dfs[i] = to_datetime(dfs[i])
        dfs[i].interpolate(method='polynomial', order = 5, inplace = True, limit = 100, limit_direction = 'both', axis = 1)
        dfs[i].fillna(0)
    return dfs

# %%
'''
Functions for RNN time series prediction
'''
def process_data(X, y, split_point, time_step, data_memory):
    '''
    Inputs: X, y, split_point, time_step, data_memory
    Splits data into training and testing data
    Outputs: X_train, X_test, y_train, y_test
    '''
    X_norm, X_attrs, y_norm, y_attrs = normalise(X, y)
    split_point = int(X_norm.shape[0] *split_point)
    y_norm = np.roll(y_norm, -time_step)
    nrows = X_norm.shape[0]
    samples = X_norm.shape[1]
    X_norm = np.repeat(X_norm, data_memory, 0).reshape(nrows, data_memory, samples)
    x_train, x_test, y_train, y_test = train_test_split(X_norm, y_norm, split_point)
    return x_train, x_test, y_train, y_test, nrows, samples, X_norm, y_norm, X_attrs, y_attrs

def normalise(X, y):
    '''
    Inputs: X, y
    Normalises the data by subtracting the mean and dividing by the standard deviation
    Outputs : X_norm, y_norm, X_attrs, y_attrs
    '''
    X_attrs = np.zeros((X.shape[-1], 2))
    y_attrs = np.zeros((y.shape[-1], 2))
    X_norm = np.zeros(X.shape)
    y_norm = np.zeros(y.shape)
    for i in range(X.shape[-1]):
        X_attrs[i, :] = [np.mean(X[:, i]), np.var(X[:, i])]
        X_norm[:, i] = (X[:, i] - np.mean(X[:, i]))/np.var(X[:, i])**0.5
    for i in range(y.shape[-1]):
        y_attrs[i, :] = [np.mean(y[:, i]), np.var(y[:, i])]
        y_norm[:, i] = (y[:, i] - np.mean(y[:, i]))/np.var(y[:, i])**0.5 
    return X_norm, X_attrs, y_norm, y_attrs

def train_test_split(X, y, split_point):
    '''
    Splits the data into training and testing data
    '''
    x_train = X[:split_point, :, :]
    x_test = X[split_point:, :, :]
    y_train = y[:split_point]
    y_test = y[split_point:]
    return x_train, x_test, y_train, y_test
        
def create_model(layers, input_shape, print_summary):
    '''
    Creates a model with the specified layers
    '''
    model = keras.Sequential(layers)
    model.build(input_shape=input_shape)
    model.compile(loss='mse', optimizer='adam', metrics = [tf.keras.metrics.MeanSquaredError()])
    if print_summary:
        model.summary()
    return model

def run_model(X, y, time_step, data_memory, epochs, batch_size, model_layer, split_point, print_summary = False):
    '''
    Inputs: X, y, time_step, data_memory, epochs, batch_size, model_layer, split_point
    Runs the model on the data
    Outputs: model, history
    '''
    x_train, x_test, y_train, y_test, nrows, samples, X_norm, y_norm, X_attrs, y_attrs = process_data(X, y, split_point, time_step, data_memory)
    input_shape = (x_train.shape[0], data_memory, samples)
    model = create_model(model_layer, input_shape, print_summary)
    history = model.fit(x_train, y_train, validation_split = 0.1, epochs= epochs , batch_size=batch_size)
    y_pred_norm = np.concatenate((model.predict(x_train[:, :, :]), model.predict(x_test[:, :, :])))
    y_pred_norm = np.roll(y_pred_norm, 1, axis = 1)
    y_pred = y_pred_norm *y_attrs[:, 1]**0.5 + y_attrs[:, 0]
    return y_pred, history

# %%
'''
Regression stuff
'''

def run_regr(X, y, t, regr):
    regr.fit(X, y)
    nrows = X.shape[0]
    y_reg = np.zeros(nrows)  
    for i in range(nrows):
        y_reg[i] = regr.predict(np.array([X[i, :]]))
    total_loss, loss = cal_loss(y, y_reg, nrows)
    return regr, total_loss, loss, y_reg

def cal_loss(y, y_reg, nrows):
    abs_loss, per_loss = np.zeros(nrows), np.zeros(nrows)
    for i in range(nrows):
        abs_loss[i] = np.abs(y[i] - y_reg[i])
        if y[i] > 0:
            per_loss[i] = abs_loss[i] / y[i]
    total_loss, loss = np.sum(abs_loss)/ nrows, np.sum(per_loss)/ nrows
    return total_loss, loss

# %%
'''
Loads in gross domestic product, hours worked and employees data
Returns GDP per employee and GDP per hour worked
'''
GDP_df =  load_df('./data/GDP_per_quarter_2.xlsx') * 1e6
HW_df = load_df('./data/hours_worked.xlsx')
employees_df = load_df('./data/Employees.xlsx') * 1e3
per_employee_df, per_HW_df = create_per_employeer(GDP_df, HW_df, employees_df)

#per_HW_df.iloc[4, :].T.plot(legend = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\ISAACE~1\AppData\Local\Temp/ipykernel_4568/2782489118.py in <module>
#       3 Returns GDP per employee and GDP per hour worked
#       4 '''
# ----> 5 GDP_df =  load_df('./data/GDP_per_quarter_2.xlsx') * 1e6
#       6 HW_df = load_df('./data/hours_worked.xlsx')
#       7 employees_df = load_df('./data/Employees.xlsx') * 1e3
#
# C:\Users\ISAACE~1\AppData\Local\Temp/ipykernel_4568/1272353484.py in load_df(file_name, sheet)
#       6     Load a file into a data frame that is quarterly from the Eurostat website
#       7     '''
# ----> 8     df = pd.read_excel(file_name, sheet_name=sheet)
#       9     df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
#      10     df.replace(':', np.nan, inplace=True)
#
# C:\Apps\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\Apps\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# C:\Apps\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1189                 ext = "xls"
#    1190             else:
# -> 1191                 ext = inspect_excel_format(
#    1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#
# C:\Apps\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(content_or_path, storage_options)
#    1068         content_or_path = BytesIO(content_or_path)
#    1069
# -> 1070     with get_handle(
#    1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#
# C:\Apps\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/GDP_per_quarter_2.xlsx'

# %%
'''
Depression data
'''
dep_df = pd.read_csv('data/depression_by_age.csv') 
dep_df = dep_df.drop(['Prevalence - Depressive disorders - Sex: Both - Age: 10 to 14 (Percent)','Prevalence - Depressive disorders - Sex: Both - Age: All Ages (Percent)','Prevalence - Depressive disorders - Sex: Both - Age: 70+ years (Percent)','Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)', 'Prevalence - Depressive disorders - Sex: Both - Age: 15-49 years (Percent)'],axis=1)
a = ['Belgium','Bulgaria','Denmark','Germany','Estonia','Ireland','Greece','Spain','France','Croatia','Italy','Cyprus','Latvia','Lithuania','Luxemburg','Hungary','Malta','Netherlands','Austria','Poland','Portugal','Romania','Slovenia','Slovakia','Finland','Sweden','Iceland','Norway','Switzerland','United Kingdom','Montenegro','North Macedonia','Serbia','Turkey']
dep_df = dep_df[dep_df['Entity'].isin(a)]
dep_df['Age:15-69_depression_average']=dep_df.iloc[:,3:7].mean(axis=1,skipna=True)
dep_df = dep_df.pivot_table('Age:15-69_depression_average', ['Entity', 'Code'], 'Year')
dep_df = dep_df.reset_index('Code')
del dep_df['Code']
dep_quarterly_df = yearly_to_quarterly(dep_df)

'''
Education data
'''
education_dfs = [None] * 4
for i in range(4):
    education_dfs[i] = load_df('./data/Education.xlsx', 'Sheet ' + str(4*i + 1))
    education_dfs[i] = yearly_to_quarterly(education_dfs[i])
    education_dfs[i] = education_dfs[i].rename({'Germany (until 1990 former territory of the FRG)': 'Germany'})

'''
Inflation data
'''
inf_df = pd.read_csv('data/Quarterly_infilation.csv')
inf_df =inf_df.drop(['SUBJECT', 'MEASURE','FREQUENCY','Flag Codes'], axis=1)
inf_df = inf_df.pivot_table('Value', ['LOCATION', 'INDICATOR'], 'TIME')
inf_df = country_code_to_name(inf_df)
inf_df = inf_df.reset_index('INDICATOR')
del inf_df['INDICATOR']
inf_df = inf_df.rename({'Germany (until 1990 former territory of the FRG)': 'Germany'})

'''
Unemployment data
'''
unem_df = pd.read_csv('./data/unem.csv')
unem_df.fillna(0)
unem_df = unem_df[['LOCATION', 'TIME', 'Value']]
unem_df = unem_df.pivot_table('Value',  ['LOCATION'],'TIME')
unem_df = country_code_to_name(unem_df)

# %%
'''
Combine all dataframes and create a numpy array of the data
Data = [Country, Time, Feature]
'''
dfs = [per_employee_df, per_HW_df] + education_dfs + [inf_df, unem_df, dep_quarterly_df]
matched_dfs = match_df(dfs)
data = np.zeros((len(matched_dfs[0].index), len(matched_dfs[0].columns),  len(matched_dfs)))
for i in range(len(matched_dfs)):
    data[:, :, i] = matched_dfs[i].to_numpy(dtype=np.float64)
matched_dfs[0].index, matched_dfs[0].columns
# Out:
# (Index(['Austria', 'Belgium', 'Estonia', 'Finland', 'France', 'Germany',
#         'Greece', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Netherlands',
#         'Portugal', 'Slovenia', 'Spain'],
#        dtype='object', name='TIME'),
#  Index(['2008-Q1', '2008-Q2', '2008-Q3', '2008-Q4', '2009-Q1', '2009-Q2',
#         '2009-Q3', '2009-Q4', '2010-Q1', '2010-Q2', '2010-Q3', '2010-Q4',
#         '2011-Q1', '2011-Q2', '2011-Q3', '2011-Q4', '2012-Q1', '2012-Q2',
#         '2012-Q3', '2012-Q4', '2013-Q1', '2013-Q2', '2013-Q3', '2013-Q4',
#         '2014-Q1', '2014-Q2', '2014-Q3', '2014-Q4', '2015-Q1', '2015-Q2',
#         '2015-Q3', '2015-Q4', '2016-Q1', '2016-Q2', '2016-Q3', '2016-Q4',
#         '2017-Q1', '2017-Q2', '2017-Q3', '2017-Q4', '2018-Q1', '2018-Q2',
#         '2018-Q3', '2018-Q4', '2019-Q1', '2019-Q2', '2019-Q3', '2019-Q4'],
#        dtype='object'))

# %% [markdown]
# Index(['Austria', 'Belgium', 'Estonia', 'Finland', 'France', 'Germany',
#        'Greece', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Netherlands',
#        'Portugal', 'Slovenia', 'Spain']
# ['2008-Q1', '2008-Q2', '2008-Q3', '2008-Q4', '2009-Q1', '2009-Q2',
#        '2009-Q3', '2009-Q4', '2010-Q1', '2010-Q2', '2010-Q3', '2010-Q4',
#        '2011-Q1', '2011-Q2', '2011-Q3', '2011-Q4', '2012-Q1', '2012-Q2',
#        '2012-Q3', '2012-Q4', '2013-Q1', '2013-Q2', '2013-Q3', '2013-Q4',
#        '2014-Q1', '2014-Q2', '2014-Q3', '2014-Q4', '2015-Q1', '2015-Q2',
#        '2015-Q3', '2015-Q4', '2016-Q1', '2016-Q2', '2016-Q3', '2016-Q4',
#        '2017-Q1', '2017-Q2', '2017-Q3', '2017-Q4', '2018-Q1', '2018-Q2',
#        '2018-Q3', '2018-Q4', '2019-Q1', '2019-Q2', '2019-Q3', '2019-Q4']

# %%
dfs = [per_employee_df, per_HW_df] + education_dfs + [inf_df, unem_df, dep_quarterly_df]
extended_dfs = extend_df(dfs)
extended_dfs[0].iloc[1, :].plot()

'''
Extended data is sparse so doesn't work well
data = np.zeros((len(extended_dfs[0].index), len(extended_dfs[0].columns),  len(extended_dfs)))
for i in range(len(extended_dfs)):
    data[:, :, i] = extended_dfs[i].to_numpy(dtype=np.float64)
data = np.nan_to_num(data, copy=True, nan=0.0)
'''
# Out:
# "\nExtended data is sparse so doesn't work well\ndata = np.zeros((len(extended_dfs[0].index), len(extended_dfs[0].columns),  len(extended_dfs)))\nfor i in range(len(extended_dfs)):\n    data[:, :, i] = extended_dfs[i].to_numpy(dtype=np.float64)\ndata = np.nan_to_num(data, copy=True, nan=0.0)\n"

# %%
extended_dfs[1].iloc[:, :].T.plot(legend = False)
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression

# %%
import matplotlib.dates as mdates
X = data[0, :, 2:]
y = data[0, :, 1]
t = np.linspace(0, y.shape[0], y.shape[0])


regr, total_loss, loss, y_reg = run_regr(X, y, t, RandomForestRegressor())
print('Total Loss: ', total_loss, 'Loss: ', loss)
colours = ['b', 'r']
t = np.arange('2008-01', '2019-12',np.timedelta64(3,'M'), dtype='datetime64')
fig, (ax1) = plt.subplots(1, 1)
ax1.plot(t, y, colours[0], t, y_reg, colours[1])
ax1.set(xlabel='Time', ylabel='GDP per hour worked')
ax1.legend(['GDP per Hour Worked', 'Predicted GDP per Hour Worked'])
plt.savefig('figures/regression.png')
# Out:
# Total Loss:  7.808775207896389 Loss:  0.012519400141053016

# %%
'''
Attempting to vary values in regression to assess impact on productivity
'''
for i in range(X.shape[1]):
    X = data[0, :, 2:]
    y = data[0, :, 0]
    regr = RandomForestRegressor()
    regr.fit(X, y)
    X[:, i] = X[:, i] *2
    y_pred = regr.predict(X)
    t = np.linspace(0, y.shape[0], y.shape[0])
    total_loss, abs_loss = cal_loss(y, y_pred, t.size)
    print(total_loss, abs_loss)
    colours = ['b', 'r']
    fig, (ax1) = plt.subplots(1, 1)
    ax1.plot(t, y, colours[0], t, y_pred, colours[1])
    ax1.set(xlabel='Time', ylabel='GDP per hour worked')
    ax1.legend(['GDP per hour worked', 'GDP per hour worked predicted'])
plt.savefig('figures/varying_value_regression.png')
# Out:
# 514.0676357556343 0.021168242132434806
# 807.5468845565165 0.03672611944719714
# 361.00188886182247 0.015201744547397304
# 677.9188797326016 0.03063805520162478
# 509.3043508586852 0.022053953570219303
# 574.7711295711518 0.02454320936404311
# 289.48514449834283 0.012406683674801489

# %%
'''
Regression on a variety of countries
'''
y1, y, X = np.split(data[:2,:,:], [1,2], axis=2)
y = y.reshape(y.shape[0], y.shape[1])
y_reg = np.zeros((y.shape))
loss = np.zeros((y.shape[0], 2))

for i in range(y.shape[0]):
    regr = RandomForestRegressor()
    regr.fit(X[i, :, :], y[i, :])
    y_reg[i, :] = regr.predict(X[i, :, :])
    t = np.linspace(0, y.shape[1], y.shape[1])
    loss[i, :] = cal_loss(y[i, :], y_reg[i, :], t.size)

print(loss)


def plot_regr(t, y, y_reg, colours, legend, labels, title):
    fig, (ax1) = plt.subplots(1, 1)
    handle1 = ax1.plot(t, y.T, colours[0], label = legend[0])[0]
    handle2 = ax1.plot(t, y_reg.T, colours[1], label = legend[1])[0]
    ax1.set(xlabel=labels[0], ylabel=labels[1])
    ax1.legend(handles = [handle1, handle2], loc='upper left')
    plt.savefig(title)

colours = ['b', 'r']
legend = ['GDP per hour worked', 'GDP per hour worked predicted']
labels = ['Time', 'GDP per hour worked']
title = 'figures/countries_regression.png'
plot_regr(t, y, y_reg, colours, legend, labels, title)
colours = ['b', 'g', 'k', 'r', 'o', 'y']
fig, (ax1) = plt.subplots(1, 1)

ax1.plot(t, y.T, colours[:2])
ax1.plot(t, y_reg.T, colours[2:])
ax1.set(xlabel='Time', ylabel='GDP per hour worked')
ax1.legend(['GDP per HW Austria', 'GDP per HW Austria pred', 'GDP per HW Belgium', 'GDP per HW Belgium predicted'])
plt.savefig('figures/countries_regression.png')
# Out:
# [[ 7.60249005  0.01206953]
#  [11.49572883  0.01628912]]

# %%
'''
Making a dataframe in Neural Prophet format
'''
per_employee_df, per_HW_df = create_per_employeer(GDP_df, HW_df, employees_df)
per_HW_df = to_datetime(per_HW_df)
per_HW_df = per_HW_df.T
per_HW_df.reset_index(inplace=True)
belgium_df = per_HW_df[['index', 'Belgium']].copy()
belgium_df.columns = ['ds', 'y']
belgium_df['ds'] = pd.to_datetime(belgium_df['ds'])
train_df = belgium_df.head(45)
test_df = belgium_df.tail(10)

# %%
'''
Attemping to predict the future with Neural Prophet
'''

'''
m = NeuralProphet()
m.fit(train_df)
'''
# Out:
# '\nm = NeuralProphet()\nm.fit(train_df)\n'

# %%
'''
Transfer Entropy
Requires numpy 1.21 or less
'''
X = data[1, :, 8]
y = data[1, :, 0]
#te.te_compute(X, y, k=1, embedding=1, safetyCheck=True, GPU=False)

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size=0.5, random_state=0)

# %%
'''
Fourier transform and frequency analysis
'''
y_freq = np.fft.fft(y)
t_freq = np.linspace(0, y.shape[0], y.shape[0])
plt.plot(t_freq, y_freq)
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Apps\lib\site-packages\matplotlib\cbook\__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
'''
Mutual information, F-statistic and R-statistic between features and target
'''
X = data[1, :, 1:]
y = data[1, :, 0]
mi = mutual_info_regression(X, y)
mi /= np.max(mi)
f_test, _ = f_regression(X, y)
f_test /= np.max(f_test)
corr = r_regression(X, y)
corr /= np.max(corr)



mi, f_test, corr
# Out:
# (array([1.        , 0.32316171, 0.31207247, 0.18897412, 0.27294893,
#         0.10606819, 0.03261111, 0.16865681]),
#  array([1.00000000e+00, 2.13027660e-02, 2.13027660e-02, 2.82153940e-03,
#         1.63964235e-02, 2.13257891e-04, 7.78999339e-04, 8.80763774e-03]),
#  array([ 1.        , -0.90815698,  0.90815698,  0.61608728,  0.8847625 ,
#         -0.20996431, -0.37979531, -0.81097251]))

# %%
decomposition = sm.tsa.seasonal_decompose(y, model='additive', period=4)
fig = decomposition.plot()
plt.savefig('figures/seasonal_decomposition.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ISAACE~1\AppData\Local\Temp/ipykernel_4568/412285502.py in <module>
# ----> 1 decomposition = sm.tsa.seasonal_decompose(y, model='additive', period=4)
#       2 fig = decomposition.plot()
#       3 plt.savefig('figures/seasonal_decomposition.png')
#
# NameError: name 'sm' is not defined

# %%
X = data[1, 2:-2, 6:10]
y = decomposition.trend[2:-2]
t = np.linspace(0, y.shape[0], y.shape[0])

regr, total_loss, loss, y_reg = run_regr(X, y, t, RandomForestRegressor())
print(total_loss, loss)
# Out:
# 110.4088244694176 0.004473187220620949

# %%
X = data[1, 2:-2, 6:10]
y = decomposition.seasonal[2:-2]
t = np.linspace(0, y.shape[0], y.shape[0])

regr, loss, y_pred = run_regr(X, y, t, RandomForestRegressor())
print(total_loss, loss)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ISAACE~1\AppData\Local\Temp/ipykernel_2168/3882309663.py in <module>
#       3 t = np.linspace(0, y.shape[0], y.shape[0])
#       4
# ----> 5 regr, loss, y_pred = run_regr(X, y, t, RandomForestRegressor())
#       6 print(total_loss, loss)
#
# ValueError: too many values to unpack (expected 3)

# %%
y = data[0, :, 1]
t = np.linspace(0, y.shape[0], y.shape[0])
plot_acf(y, lags=20, alpha = 0.1)
plot_pacf(y, lags=20, alpha = 0.01, method='ywm')
model = sm.tsa.statespace.SARIMAX(y, order=(1, 1, 1), seasonal_order = (1, 1, 1, 4))
res = model.fit()
plt.figure()
res.plot_diagnostics(figsize=(15, 12))
forecast_values = res.get_forecast(steps=50)
plt.figure()
ax = plt.plot(t, y, np.linspace(t[-1], t[-1] + 50, 50), forecast_values.predicted_mean)
plt.savefig('figures/sarima_model.png')
t = np.arange('2008-01', '2032-07',np.timedelta64(3,'M'), dtype='datetime64')
fig, (ax1) = plt.subplots(1, 1)
ax1.plot(t[:48], y, t[48:], forecast_values.predicted_mean)
ax1.set(xlabel='Time', ylabel='GDP per hour worked')
ax1.legend(['GDP per Hour Worked', 'Predicted GDP per Hour Worked'])
plt.savefig('figures/sarima_model.png')
forecast_values.se_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ISAACE~1\AppData\Local\Temp/ipykernel_4568/790565155.py in <module>
# ----> 1 y = data[0, :, 1]
#       2 t = np.linspace(0, y.shape[0], y.shape[0])
#       3 plot_acf(y, lags=20, alpha = 0.1)
#       4 plot_pacf(y, lags=20, alpha = 0.01, method='ywm')
#       5 model = sm.tsa.statespace.SARIMAX(y, order=(1, 1, 1), seasonal_order = (1, 1, 1, 4))
#
# NameError: name 'data' is not defined

# %%
'''
RNN on the data
'''
time_step, data_memory, epochs, batch_size, split_point = 5, 8, 40, 4, 0.8

load_model_bool, load_model, save_model, save_fig = False, 'EU_model', 'EU_model', 'EU'
model_layer = [layers.GRU(16,activation= 'tanh', dropout = 0.1, recurrent_dropout = 0.1, return_sequences=False),
                layers.Dense(2)]

X = data[0, :, 2:]
y = data[0, :, 0:1]
t = np.linspace(0, y.shape[0], y.shape[0])
y_pred, history = run_model(X, y, time_step, data_memory, epochs, batch_size, model_layer, split_point)

t = np.arange('2008-01', '2020-07',np.timedelta64(3,'M'), dtype='datetime64')
fig, (ax1) = plt.subplots(1, 1)
plt.plot( t[:48], y, 'g', t[time_step - 3:], y_pred[:, 0], 'r')
ax1.set(xlabel='Time', ylabel='GDP per hour worked')
ax1.legend(['GDP per Hour Worked', 'Predicted GDP per Hour Worked'])
plt.savefig('figures/rnn_model.png')
train_loss = history.history['loss']
val_loss = history.history['val_loss']
print(train_loss[-1], val_loss[-1])
# Out:
# Epoch 1/40
# 9/9 [==============================] - 3s 89ms/step - loss: 0.7372 - mean_squared_error: 0.7372 - val_loss: 0.9848 - val_mean_squared_error: 0.9848
# Epoch 2/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5995 - mean_squared_error: 0.5995 - val_loss: 0.8485 - val_mean_squared_error: 0.8485
# Epoch 3/40
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4330 - mean_squared_error: 0.4330 - val_loss: 0.7148 - val_mean_squared_error: 0.7148
# Epoch 4/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3876 - mean_squared_error: 0.3876 - val_loss: 0.6379 - val_mean_squared_error: 0.6379
# Epoch 5/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3200 - mean_squared_error: 0.3200 - val_loss: 0.5544 - val_mean_squared_error: 0.5544
# Epoch 6/40
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2736 - mean_squared_error: 0.2736 - val_loss: 0.4793 - val_mean_squared_error: 0.4793
# Epoch 7/40
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2747 - mean_squared_error: 0.2747 - val_loss: 0.4345 - val_mean_squared_error: 0.4345
# Epoch 8/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2444 - mean_squared_error: 0.2444 - val_loss: 0.3765 - val_mean_squared_error: 0.3765
# Epoch 9/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2248 - mean_squared_error: 0.2248 - val_loss: 0.3190 - val_mean_squared_error: 0.3190
# Epoch 10/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2178 - mean_squared_error: 0.2178 - val_loss: 0.3141 - val_mean_squared_error: 0.3141
# Epoch 11/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1905 - mean_squared_error: 0.1905 - val_loss: 0.2994 - val_mean_squared_error: 0.2994
# Epoch 12/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1782 - mean_squared_error: 0.1782 - val_loss: 0.3094 - val_mean_squared_error: 0.3094
# Epoch 13/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1602 - mean_squared_error: 0.1602 - val_loss: 0.2938 - val_mean_squared_error: 0.2938
# Epoch 14/40
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1586 - mean_squared_error: 0.1586 - val_loss: 0.2794 - val_mean_squared_error: 0.2794
# Epoch 15/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1478 - mean_squared_error: 0.1478 - val_loss: 0.2554 - val_mean_squared_error: 0.2554
# Epoch 16/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1426 - mean_squared_error: 0.1426 - val_loss: 0.2409 - val_mean_squared_error: 0.2409
# Epoch 17/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1274 - mean_squared_error: 0.1274 - val_loss: 0.2318 - val_mean_squared_error: 0.2318
# Epoch 18/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1444 - mean_squared_error: 0.1444 - val_loss: 0.2292 - val_mean_squared_error: 0.2292
# Epoch 19/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1274 - mean_squared_error: 0.1274 - val_loss: 0.2220 - val_mean_squared_error: 0.2220
# Epoch 20/40
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1060 - mean_squared_error: 0.1060 - val_loss: 0.2088 - val_mean_squared_error: 0.2088
# Epoch 21/40
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1229 - mean_squared_error: 0.1229 - val_loss: 0.2114 - val_mean_squared_error: 0.2114
# Epoch 22/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1045 - mean_squared_error: 0.1045 - val_loss: 0.2018 - val_mean_squared_error: 0.2018
# Epoch 23/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1199 - mean_squared_error: 0.1199 - val_loss: 0.2113 - val_mean_squared_error: 0.2113
# Epoch 24/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1204 - mean_squared_error: 0.1204 - val_loss: 0.2110 - val_mean_squared_error: 0.2110
# Epoch 25/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1117 - mean_squared_error: 0.1117 - val_loss: 0.1956 - val_mean_squared_error: 0.1956
# Epoch 26/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1133 - mean_squared_error: 0.1133 - val_loss: 0.1911 - val_mean_squared_error: 0.1911
# Epoch 27/40
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1100 - mean_squared_error: 0.1100 - val_loss: 0.1943 - val_mean_squared_error: 0.1943
# Epoch 28/40
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1226 - mean_squared_error: 0.1226 - val_loss: 0.1942 - val_mean_squared_error: 0.1942
# Epoch 29/40
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1034 - mean_squared_error: 0.1034 - val_loss: 0.1784 - val_mean_squared_error: 0.1784
# Epoch 30/40
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1070 - mean_squared_error: 0.1070 - val_loss: 0.1855 - val_mean_squared_error: 0.1855
# Epoch 31/40
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1075 - mean_squared_error: 0.1075 - val_loss: 0.1843 - val_mean_squared_error: 0.1843
# Epoch 32/40
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0966 - mean_squared_error: 0.0966 - val_loss: 0.1870 - val_mean_squared_error: 0.1870
# Epoch 33/40
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1080 - mean_squared_error: 0.1080 - val_loss: 0.1851 - val_mean_squared_error: 0.1851
# Epoch 34/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0882 - mean_squared_error: 0.0882 - val_loss: 0.1805 - val_mean_squared_error: 0.1805
# Epoch 35/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1025 - mean_squared_error: 0.1025 - val_loss: 0.1700 - val_mean_squared_error: 0.1700
# Epoch 36/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0979 - mean_squared_error: 0.0979 - val_loss: 0.1821 - val_mean_squared_error: 0.1821
# Epoch 37/40
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1050 - mean_squared_error: 0.1050 - val_loss: 0.1830 - val_mean_squared_error: 0.1830
# Epoch 38/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0909 - mean_squared_error: 0.0909 - val_loss: 0.1781 - val_mean_squared_error: 0.1781
# Epoch 39/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1119 - mean_squared_error: 0.1119 - val_loss: 0.1829 - val_mean_squared_error: 0.1829
# Epoch 40/40
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1095 - mean_squared_error: 0.1095 - val_loss: 0.1881 - val_mean_squared_error: 0.1881
# 0.10952513664960861 0.18810424208641052

# %%
t = np.arange('2008-01', '2020-07',np.timedelta64(3,'M'), dtype='datetime64')
fig, (ax1) = plt.subplots(1, 1)
plt.plot( t[:48], y, 'g', t[time_step - 3:], y_pred[:, 0], 'r')
ax1.set(xlabel='Time', ylabel='GDP per hour worked')
ax1.legend(['GDP per Hour Worked', 'Predicted GDP per Hour Worked'])
plt.savefig('figures/rnn_model.png')
train_loss = history.history['loss']
val_loss = history.history['val_loss']
print(train_loss[-1], val_loss[-1])
# Out:
# 0.1014963760972023 0.19820307195186615

# %%
'''
RNN on the decomposed data
'''
time_step, data_memory, epochs, batch_size, split_point = 1, 8, 40, 4, 0.8

load_model_bool, load_model, save_model, save_fig = False, 'EU_model', 'EU_model', 'EU'
model_layer = [layers.Dense(8, activation= 'linear'),
                layers.LSTM(16,activation= 'tanh', dropout = 0.1, recurrent_dropout = 0.1, return_sequences=False),
                layers.Dense(2)]
print_summary = True
X = data[0, :, 2:]

y = data[0, :, 0:1]
X = data[1, 2:-2, 2:]
y = np.array([decomposition.trend[2:-2]]).T
t = np.linspace(0, y.shape[0], y.shape[0])
y_pred, history = run_model(X, y, time_step, data_memory, epochs, batch_size, model_layer, split_point)

plt.plot(t, y, 'g', t + time_step - 2, y_pred[:, 0], 'r')
train_loss = history.history['loss']
val_loss = history.history['val_loss']

y = np.array([decomposition.seasonal[2:-2]]).T
y_pred, history = run_model(X, y, time_step, data_memory, epochs, batch_size, model_layer, split_point)
plt.plot(t, y, 'g', t + time_step - 2, y_pred[:, 0], 'r')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (35, 8, 8)                64
#
#  lstm_1 (LSTM)               (35, 16)                  1600
#
#  dense_3 (Dense)             (35, 2)                   34
#
# =================================================================
# Total params: 1,698
# Trainable params: 1,698
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 8/8 [==============================] - 5s 69ms/step - loss: 1.2938 - mean_squared_error: 1.2938 - val_loss: 2.2839 - val_mean_squared_error: 2.2839
# Epoch 2/40
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9258 - mean_squared_error: 0.9258 - val_loss: 1.8830 - val_mean_squared_error: 1.8830
# Epoch 3/40
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6309 - mean_squared_error: 0.6309 - val_loss: 1.5482 - val_mean_squared_error: 1.5482
# Epoch 4/40
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5106 - mean_squared_error: 0.5106 - val_loss: 1.2985 - val_mean_squared_error: 1.2985
# Epoch 5/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3776 - mean_squared_error: 0.3776 - val_loss: 1.1155 - val_mean_squared_error: 1.1155
# Epoch 6/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2752 - mean_squared_error: 0.2752 - val_loss: 0.9776 - val_mean_squared_error: 0.9776
# Epoch 7/40
# 8/8 [==============================] - 0s 11ms/step - loss: 0.2072 - mean_squared_error: 0.2072 - val_loss: 0.8696 - val_mean_squared_error: 0.8696
# Epoch 8/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1608 - mean_squared_error: 0.1608 - val_loss: 0.7835 - val_mean_squared_error: 0.7835
# Epoch 9/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1337 - mean_squared_error: 0.1337 - val_loss: 0.7152 - val_mean_squared_error: 0.7152
# Epoch 10/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1303 - mean_squared_error: 0.1303 - val_loss: 0.6622 - val_mean_squared_error: 0.6622
# Epoch 11/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0927 - mean_squared_error: 0.0927 - val_loss: 0.6201 - val_mean_squared_error: 0.6201
# Epoch 12/40
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0836 - mean_squared_error: 0.0836 - val_loss: 0.5844 - val_mean_squared_error: 0.5844
# Epoch 13/40
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0725 - mean_squared_error: 0.0725 - val_loss: 0.5582 - val_mean_squared_error: 0.5582
# Epoch 14/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0686 - mean_squared_error: 0.0686 - val_loss: 0.5401 - val_mean_squared_error: 0.5401
# Epoch 15/40
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0581 - mean_squared_error: 0.0581 - val_loss: 0.5251 - val_mean_squared_error: 0.5251
# Epoch 16/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0525 - mean_squared_error: 0.0525 - val_loss: 0.5179 - val_mean_squared_error: 0.5179
# Epoch 17/40
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0519 - mean_squared_error: 0.0519 - val_loss: 0.5085 - val_mean_squared_error: 0.5085
# Epoch 18/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0431 - mean_squared_error: 0.0431 - val_loss: 0.4998 - val_mean_squared_error: 0.4998
# Epoch 19/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0446 - mean_squared_error: 0.0446 - val_loss: 0.4959 - val_mean_squared_error: 0.4959
# Epoch 20/40
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0461 - mean_squared_error: 0.0461 - val_loss: 0.4944 - val_mean_squared_error: 0.4944
# Epoch 21/40
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0313 - mean_squared_error: 0.0313 - val_loss: 0.4883 - val_mean_squared_error: 0.4883
# Epoch 22/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0377 - mean_squared_error: 0.0377 - val_loss: 0.4932 - val_mean_squared_error: 0.4932
# Epoch 23/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0384 - mean_squared_error: 0.0384 - val_loss: 0.4924 - val_mean_squared_error: 0.4924
# Epoch 24/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0340 - mean_squared_error: 0.0340 - val_loss: 0.4805 - val_mean_squared_error: 0.4805
# Epoch 25/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0373 - mean_squared_error: 0.0373 - val_loss: 0.4713 - val_mean_squared_error: 0.4713
# Epoch 26/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0336 - mean_squared_error: 0.0336 - val_loss: 0.4682 - val_mean_squared_error: 0.4682
# Epoch 27/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.4684 - val_mean_squared_error: 0.4684
# Epoch 28/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0369 - mean_squared_error: 0.0369 - val_loss: 0.4735 - val_mean_squared_error: 0.4735
# Epoch 29/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.4776 - val_mean_squared_error: 0.4776
# Epoch 30/40
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0308 - mean_squared_error: 0.0308 - val_loss: 0.4764 - val_mean_squared_error: 0.4764
# Epoch 31/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0309 - mean_squared_error: 0.0309 - val_loss: 0.4809 - val_mean_squared_error: 0.4809
# Epoch 32/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0312 - mean_squared_error: 0.0312 - val_loss: 0.4810 - val_mean_squared_error: 0.4810
# Epoch 33/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.4764 - val_mean_squared_error: 0.4764
# Epoch 34/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.4692 - val_mean_squared_error: 0.4692
# Epoch 35/40
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0271 - mean_squared_error: 0.0271 - val_loss: 0.4675 - val_mean_squared_error: 0.4675
# Epoch 36/40
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.4697 - val_mean_squared_error: 0.4697
# Epoch 37/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0315 - mean_squared_error: 0.0315 - val_loss: 0.4626 - val_mean_squared_error: 0.4626
# Epoch 38/40
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0307 - mean_squared_error: 0.0307 - val_loss: 0.4593 - val_mean_squared_error: 0.4593
# Epoch 39/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.4685 - val_mean_squared_error: 0.4685
# Epoch 40/40
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.4665 - val_mean_squared_error: 0.4665
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             multiple                  64
#
#  lstm_1 (LSTM)               multiple                  1600
#
#  dense_3 (Dense)             multiple                  34
#
# =================================================================
# Total params: 1,698
# Trainable params: 1,698
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 8/8 [==============================] - 5s 67ms/step - loss: 1.5639 - mean_squared_error: 1.5639 - val_loss: 1.5354 - val_mean_squared_error: 1.5354
# Epoch 2/40
# 8/8 [==============================] - 0s 18ms/step - loss: 1.3168 - mean_squared_error: 1.3168 - val_loss: 1.4241 - val_mean_squared_error: 1.4241
# Epoch 3/40
# 8/8 [==============================] - 0s 19ms/step - loss: 1.1545 - mean_squared_error: 1.1545 - val_loss: 1.3047 - val_mean_squared_error: 1.3047
# Epoch 4/40
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0939 - mean_squared_error: 1.0939 - val_loss: 1.2352 - val_mean_squared_error: 1.2352
# Epoch 5/40
# 8/8 [==============================] - 0s 18ms/step - loss: 1.0554 - mean_squared_error: 1.0554 - val_loss: 1.2104 - val_mean_squared_error: 1.2104
# Epoch 6/40
# 8/8 [==============================] - 0s 16ms/step - loss: 1.0357 - mean_squared_error: 1.0357 - val_loss: 1.1984 - val_mean_squared_error: 1.1984
# Epoch 7/40
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0147 - mean_squared_error: 1.0147 - val_loss: 1.1989 - val_mean_squared_error: 1.1989
# Epoch 8/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.9739 - mean_squared_error: 0.9739 - val_loss: 1.1966 - val_mean_squared_error: 1.1966
# Epoch 9/40
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9985 - mean_squared_error: 0.9985 - val_loss: 1.1988 - val_mean_squared_error: 1.1988
# Epoch 10/40
# 8/8 [==============================] - 0s 13ms/step - loss: 1.0054 - mean_squared_error: 1.0054 - val_loss: 1.1963 - val_mean_squared_error: 1.1963
# Epoch 11/40
# 8/8 [==============================] - 0s 13ms/step - loss: 1.0090 - mean_squared_error: 1.0090 - val_loss: 1.1967 - val_mean_squared_error: 1.1967
# Epoch 12/40
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0151 - mean_squared_error: 1.0151 - val_loss: 1.2054 - val_mean_squared_error: 1.2054
# Epoch 13/40
# 8/8 [==============================] - 0s 13ms/step - loss: 1.0399 - mean_squared_error: 1.0399 - val_loss: 1.1995 - val_mean_squared_error: 1.1995
# Epoch 14/40
# 8/8 [==============================] - 0s 14ms/step - loss: 1.0285 - mean_squared_error: 1.0285 - val_loss: 1.2096 - val_mean_squared_error: 1.2096
# Epoch 15/40
# 8/8 [==============================] - 0s 13ms/step - loss: 1.0205 - mean_squared_error: 1.0205 - val_loss: 1.2137 - val_mean_squared_error: 1.2137
# Epoch 16/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.9656 - mean_squared_error: 0.9656 - val_loss: 1.2203 - val_mean_squared_error: 1.2203
# Epoch 17/40
# 8/8 [==============================] - 0s 13ms/step - loss: 1.0011 - mean_squared_error: 1.0011 - val_loss: 1.2132 - val_mean_squared_error: 1.2132
# Epoch 18/40
# 8/8 [==============================] - 0s 14ms/step - loss: 0.9759 - mean_squared_error: 0.9759 - val_loss: 1.2241 - val_mean_squared_error: 1.2241
# Epoch 19/40
# 8/8 [==============================] - 0s 14ms/step - loss: 1.0182 - mean_squared_error: 1.0182 - val_loss: 1.2254 - val_mean_squared_error: 1.2254
# Epoch 20/40
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9936 - mean_squared_error: 0.9936 - val_loss: 1.2298 - val_mean_squared_error: 1.2298
# Epoch 21/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.9751 - mean_squared_error: 0.9751 - val_loss: 1.2264 - val_mean_squared_error: 1.2264
# Epoch 22/40
# 8/8 [==============================] - 0s 14ms/step - loss: 1.0375 - mean_squared_error: 1.0375 - val_loss: 1.2237 - val_mean_squared_error: 1.2237
# Epoch 23/40
# 8/8 [==============================] - 0s 14ms/step - loss: 0.9865 - mean_squared_error: 0.9865 - val_loss: 1.2103 - val_mean_squared_error: 1.2103
# Epoch 24/40
# 8/8 [==============================] - 0s 16ms/step - loss: 0.9720 - mean_squared_error: 0.9720 - val_loss: 1.2163 - val_mean_squared_error: 1.2163
# Epoch 25/40
# 8/8 [==============================] - 0s 14ms/step - loss: 0.9882 - mean_squared_error: 0.9882 - val_loss: 1.2280 - val_mean_squared_error: 1.2280
# Epoch 26/40
# 8/8 [==============================] - 0s 13ms/step - loss: 1.0019 - mean_squared_error: 1.0019 - val_loss: 1.2359 - val_mean_squared_error: 1.2359
# Epoch 27/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.9858 - mean_squared_error: 0.9858 - val_loss: 1.2300 - val_mean_squared_error: 1.2300
# Epoch 28/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.9829 - mean_squared_error: 0.9829 - val_loss: 1.2298 - val_mean_squared_error: 1.2298
# Epoch 29/40
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9883 - mean_squared_error: 0.9883 - val_loss: 1.2279 - val_mean_squared_error: 1.2279
# Epoch 30/40
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9742 - mean_squared_error: 0.9742 - val_loss: 1.2395 - val_mean_squared_error: 1.2395
# Epoch 31/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.9842 - mean_squared_error: 0.9842 - val_loss: 1.2387 - val_mean_squared_error: 1.2387
# Epoch 32/40
# 8/8 [==============================] - 0s 16ms/step - loss: 0.9581 - mean_squared_error: 0.9581 - val_loss: 1.2502 - val_mean_squared_error: 1.2502
# Epoch 33/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.9596 - mean_squared_error: 0.9596 - val_loss: 1.2367 - val_mean_squared_error: 1.2367
# Epoch 34/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.9507 - mean_squared_error: 0.9507 - val_loss: 1.2497 - val_mean_squared_error: 1.2497
# Epoch 35/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.9447 - mean_squared_error: 0.9447 - val_loss: 1.2615 - val_mean_squared_error: 1.2615
# Epoch 36/40
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9604 - mean_squared_error: 0.9604 - val_loss: 1.2496 - val_mean_squared_error: 1.2496
# Epoch 37/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.9756 - mean_squared_error: 0.9756 - val_loss: 1.2449 - val_mean_squared_error: 1.2449
# Epoch 38/40
# 8/8 [==============================] - 0s 12ms/step - loss: 1.0070 - mean_squared_error: 1.0070 - val_loss: 1.2532 - val_mean_squared_error: 1.2532
# Epoch 39/40
# 8/8 [==============================] - 0s 12ms/step - loss: 0.9599 - mean_squared_error: 0.9599 - val_loss: 1.2686 - val_mean_squared_error: 1.2686
# Epoch 40/40
# 8/8 [==============================] - 0s 13ms/step - loss: 0.9370 - mean_squared_error: 0.9370 - val_loss: 1.2969 - val_mean_squared_error: 1.2969
# [<matplotlib.lines.Line2D at 0x21a8b67bc10>,
#  <matplotlib.lines.Line2D at 0x21a8b67baf0>]

# %%
'''
Clustering of features using K-means

X = [Country, Time, Features]
Plot the clusters against properties
'''
X = data[:, 0, :]
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
plt.scatter(X[:, 0], X[:, 1], c= kmeans.labels_)

# %%
'''
Clustering of features using DBSCAN
'''
X = data[:, 0, :]
y = data[:, 1, :]
X, X_attrs, y, y_attrs = normalise(X, y)
dbs = DBSCAN(eps = 2.5, min_samples= 2).fit(X)
plt.scatter(X[:, 1], X[:, 4], c= dbs.labels_)

# %%
'''
PCA
'''
X = data[0, :, :]
pca = PCA()
pca = pca.fit_transform(X)
fig2 = plt.scatter(pca[:, 0], pca[:, 1])

# %%
X = data[0, :, 2:]
y = data[0, :, 0:2]
tsne = TSNE()
X_embedded = tsne.fit_transform(X)
fig2 = plt.scatter(X_embedded[:, 0], X_embedded[:, 1])
# Out:
# WARNING - (py.warnings._showwarnmsg) - C:\Apps\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
#
# WARNING - (py.warnings._showwarnmsg) - C:\Apps\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
